# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">ЗАДАНИЕ. <b>Дескриптивный анализ данных</b> </div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin.study@yandex.ru)</span></div>

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">Варианты</a></li>
#         <li><a href="#2">Задание</a></li>
#     </ol>
# </div>

# %% [markdown]
# <p>Подключение стилей оформления</p>

# %%
# %%html
# <link href="css/style.css" rel="stylesheet" type="text/css">
# Out:
# <link href="css/style.css" rel="stylesheet" type="text/css">

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. Варианты</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p>Чтобы узнать свой вариант, введите Вашу фамилию в соответвующее поле ниже и запустите ячейку:</p>

# %%
surname = "Комиссаров"  # Ваша фамилия

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 1, шаг 5 - вариант: ", variant % 5 + 1)
print("Задача № 1, шаг 11 - вариант: ", variant % 2 + 1 )
print("задача № 2 - вариант: ", variant % 4 + 1)
# Out:
# Задача № 1, шаг 5 - вариант:  1
# Задача № 1, шаг 11 - вариант:  2
# задача № 2 - вариант:  2

# %% [markdown]
# <div class="msg-block msg-warning">
#   <p class="msg-text-warn">Варианты могут не совпадать с последующими ДЗ</p>
# </div>

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. Задание</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div class="msg-block msg-imp">
#   <div class="msg-text-imp">
#       <p>СРОК СДАЧИ: до <b>-</b></p>
#       <p style="margin:0px">ПОСЛЕ СРОКА: первая неделя <b>-</b>, вторая неделя и далее до конца модуля <b>-</b>, потом <b>- баллов</b>
#       </p>
#   </div>
# </div>

# %% [markdown]
# <p><b>Задача 1.</b> Анализ индекса восприятия коррупции (Corruption Perceptions Index, CPI) (6 баллов)</p>

# %% [markdown]
# <p>1. Подключите библиотеки numpy, pandas, matplotlib</p>

# %%
import numpy as np

import pandas as pd

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <p>2. Загрузите данные из "data/CPI2021.xlsx" в DataFrame. Исходные данные и пояснения можно найти <a href="https://www.transparency.org/en/cpi/2021/index">здесь</a></p>

# %%
df = pd.read_excel('C:\\Users\\vova-\\Documents\\Jupyter//CPI2021.xlsx', sheet_name='CPI 2021', skiprows=2)
dfcpi2021 = df
dfcpi2021
# Out:
#     Country / Territory ISO3 Region  CPI score 2021  Rank  Standard error  \
# 0               Denmark  DNK  WE/EU              88     1        1.850507
# 1               Finland  FIN  WE/EU              88     1        1.248280
# 2           New Zealand  NZL     AP              88     1        1.427644
# 3                Norway  NOR  WE/EU              85     4        1.072085
# 4             Singapore  SGP     AP              85     4        1.159654
# ..                  ...  ...    ...             ...   ...             ...
# 175               Yemen  YEM   MENA              16   174        2.292554
# 176           Venezuela  VEN    AME              14   177        0.991130
# 177             Somalia  SOM    SSA              13   178        1.891675
# 178               Syria  SYR   MENA              13   178        1.578473
# 179         South Sudan  SSD    SSA              11   180        0.409076
#
#      Number of sources   Lower CI  Upper CI  African Development Bank CPIA  \
# ...

# %% [markdown]
# <p>3. Отсортируйте данные по убыванию индекса DataFrame</p>

# %%
dfmain.sort_index()
# Out:
#     Country / Territory ISO3 Region  CPI score 2021  Rank  Standard error  \
# 0               Denmark  DNK  WE/EU              88     1        1.850507
# 1               Finland  FIN  WE/EU              88     1        1.248280
# 2           New Zealand  NZL     AP              88     1        1.427644
# 3                Norway  NOR  WE/EU              85     4        1.072085
# 4             Singapore  SGP     AP              85     4        1.159654
# ..                  ...  ...    ...             ...   ...             ...
# 175               Yemen  YEM   MENA              16   174        2.292554
# 176           Venezuela  VEN    AME              14   177        0.991130
# 177             Somalia  SOM    SSA              13   178        1.891675
# 178               Syria  SYR   MENA              13   178        1.578473
# 179         South Sudan  SSD    SSA              11   180        0.409076
#
#      Number of sources   Lower CI  Upper CI  African Development Bank CPIA  \
# ...

# %% [markdown]
# <div><p>4. Отобразите данные по индексу CPI за 2021 год в виде горизонтального столбчатого графика. Примерный вид графика приведен ниже</p>
# <img src="img/cpi_2016_.png"></div>

# %%
plt.rcParams.update({'font.size': 18})
dfmain.plot.barh(x="Country / Territory", y="CPI score 2021", title="CPI score 2021 horizontal bars", figsize=(12,80));

# %% [markdown]
# <p>5. Сформируйте DataFrame из исходного для региона в соответствии с Вашим вариантом</p>
# <p><b>Вариант 1.</b> Asia Pacific</p>
# <p><b>Вариант 2.</b> Americas</p>
# <p><b>Вариант 3.</b> Europe and Central Asia</p>
# <p><b>Вариант 4.</b> Middle East and North Africa</p>
# <p><b>Вариант 5.</b> Sub Saharan Africa</p>

# %%
df = pd.read_excel('C:\\Users\\vova-\\Documents\\Jupyter//CPI2021.xlsx', sheet_name='CPI Timeseries 2012 - 2021', skiprows=2)

dfAsia=df[df["Region"].apply(lambda r: r == "AP")]

# %% [markdown]
# <p>6. Выведите данные DataFrame'a</p>

# %%
dfAsia
# Out:
#     Country / Territory ISO3 Region  CPI score 2021  Rank 2021  Sources 2021  \
# 1           New Zealand  NZL     AP            88.0        1.0           8.0
# 3             Singapore  SGP     AP            85.0        4.0           9.0
# 11            Hong Kong  HKG     AP            76.0       12.0           8.0
# 17            Australia  AUS     AP            73.0       18.0           9.0
# 19                Japan  JPN     AP            73.0       18.0           9.0
# 24               Bhutan  BTN     AP            68.0       25.0           4.0
# 25               Taiwan  TWN     AP            68.0       25.0           8.0
# 31         Korea, South  KOR     AP            62.0       32.0          10.0
# 44                 Fiji  FJI     AP            55.0       45.0           3.0
# 61             Malaysia  MYS     AP            48.0       62.0           9.0
# 67              Vanuatu  VUT     AP            45.0       66.0           3.0
# ...

# %% [markdown]
# <div><p>7. Постройте графики индекса CPI за 2012-2021для стран своего региона. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region.png">
# </div>

# %%
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = [20, 30]

dfAsia[["CPI score 2021",
        "CPI score 2020",
        "CPI score 2019",
        "CPI score 2018",
        "CPI score 2017",
        "CPI score 2016",
        "CPI score 2015",
        "CPI score 2014",
        "CPI Score 2013",
        "CPI Score 2012"]].T.plot(ylabel="CPI", title="графики индекса CPI за 2012-2021 для стран", grid=True, marker="o")
# Out:
# <AxesSubplot:title={'center':'графики индекса CPI за 2012-2021 для стран'}, ylabel='CPI'>

# %% [markdown]
# <p>8. Найдите страны с наибольшим и наименьшим значением CPI Вашего варианта региона за 2021 год</p>

# %%
max = dfAsia.loc[dfAsia["CPI score 2021"].idxmax(),"Country / Territory"]
max
# Out:
# 'New Zealand'

# %%
min = dfAsia.loc[dfAsia["CPI score 2021"].idxmin(),'Country / Territory']
min
# Out:
# 'Afghanistan'

# %% [markdown]
# <p>9. Определите средние значения за каждый год в период с 2012 по 2021</p>

# %%
dfAsia[["CPI score 2021",
        "CPI score 2020",
        "CPI score 2019",
        "CPI score 2018",
        "CPI score 2017",
        "CPI score 2016",
        "CPI score 2015",
        "CPI score 2014",
        "CPI Score 2013",
        "CPI Score 2012"]].mean()
# Out:
# CPI score 2021    45.096774
# CPI score 2020    45.290323
# CPI score 2019    44.870968
# CPI score 2018    44.387097
# CPI score 2017    44.387097
# CPI score 2016    43.866667
# CPI score 2015    42.555556
# CPI score 2014    42.703704
# CPI Score 2013    43.035714
# CPI Score 2012    42.642857
# dtype: float64

# %% [markdown]
# <div><p>10. Постройте графики индекса CPI за 2012-2021 для стран своего региона и выделите страны с наибольшим и наименьшим значением CPI за 2021 год, а также отобразите среднее значение по региону и РФ. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region_comb.png">
# </div>

# %%
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = [20, 30]

# общий график серый для фона
ax = dfAsia[["CPI score 2021",
             "CPI score 2020",
             "CPI score 2019",
             "CPI score 2018",
             "CPI score 2017",
             "CPI score 2016",
             "CPI score 2015",
             "CPI score 2014",
             "CPI Score 2013",
             "CPI Score 2012"]].T.plot(color="grey", ylabel="CPI", title="Индекс CPI за 2012-2021", grid=True, marker="o")

#Построение среднего значения CPI
dfAsia[["CPI score 2021",
        "CPI score 2020",
        "CPI score 2019",
        "CPI score 2018",
        "CPI score 2017",
        "CPI score 2016",
        "CPI score 2015",
        "CPI score 2014",
        "CPI Score 2013",
        "CPI Score 2012"]].mean().plot(ax=ax, linewidth=5, legend=True, label="MEAN", color="red")

#Построение максимального значения CPI
dfAsia[["CPI score 2021",
        "CPI score 2020",
        "CPI score 2019",
        "CPI score 2018",
        "CPI score 2017",
        "CPI score 2016",
        "CPI score 2015",
        "CPI score 2014",
        "CPI Score 2013",
        "CPI Score 2012"]].max().plot(ax=ax, linewidth=5, legend=True, label="MAX", color="green")

#Построение минимального значения CPI
dfAsia[["CPI score 2021",
        "CPI score 2020",
        "CPI score 2019",
        "CPI score 2018",
        "CPI score 2017",
        "CPI score 2016",
        "CPI score 2015",
        "CPI score 2014",
        "CPI Score 2013",
        "CPI Score 2012"]].min().plot(ax=ax, linewidth=5, legend=True, label="MIN", color="blue")
# Out:
# <AxesSubplot:title={'center':'Индекс CPI за 2012-2021'}, ylabel='CPI'>

# %% [markdown]
# <p>11. Определите, как изменилось значение показателя в соответствии с Вашим вариантом с 2012 по 2021</p>
# <p><b>Вариант 1.</b> На сколько позиций в рейтинге c 2012 по 2021</p>
# <p><b>Вариант 2.</b> На сколько процентов значение CPI с 2012 по 2021</p>

# %% [markdown]
# <div class="msg-block msg-info">
#   <p class="msg-text-info">У нескольких стран может быть одна и та же позиция в рейтинге из-за одинаковых значений индекса</p>
# </div>

# %% [markdown]
# <p>12. Выведите </p>

# %%
# формула нахождения процентов:
# (среднее значение в 2021 году - среднее значение в 2012 году) / среднее значение в 2012 году * 100%
# модуль результата укажет на чиленное значение, знак - на динамику: + на увеличение и - на уменьшение
print ("Формула: Cреднее значение в 2021 году - среднее значение в 2012 году) / среднее значение в 2012 году * 100%")
# Out:
# Cреднее значение в 2021 году - среднее значение в 2012 году) / среднее значение в 2012 году * 100%

# %%
a = dfAsia["CPI score 2021"].mean()
print ("Cреднее значение в 2021 году = ", a)
# Out:
# Cреднее значение в 2021 году =  45.096774193548384

# %%
b = dfAsia["CPI Score 2012"].mean()
print ("Cреднее значение в 2012 году = ", b)
# Out:
# Cреднее значение в 2012 году =  42.642857142857146

# %%
Procent20122021 = (a - b)*100 / b
print ("На ",Procent20122021, "% изменилось начение CPI с 2012 по 2021")
# Out:
# На  5.754579348354663 % изменилось начение CPI с 2012 по 2021

# %%
#Добавление столба по изменению CPI в наш dataframe

a = dfAsia["CPI score 2021"]
b = dfAsia["CPI Score 2012"]
Procent20122021 = (a - b)*100 / b
dfAsia['Изменение в %']=Procent20122021
dfAsia[['Country / Territory', 'Изменение в %']]
# Out:
#     Country / Territory  Изменение в %
# 1           New Zealand      -2.222222
# 3             Singapore      -2.298851
# 11            Hong Kong      -1.298701
# 17            Australia     -14.117647
# 19                Japan      -1.351351
# 24               Bhutan       7.936508
# 25               Taiwan      11.475410
# 31         Korea, South      10.714286
# 44                 Fiji            NaN
# 61             Malaysia      -2.040816
# 67              Vanuatu            NaN
# 68                China      15.384615
# 76      Solomon Islands            NaN
# 82          Timor-Leste      24.242424
# 84             Maldives            NaN
# 85                India      11.111111
# 93              Vietnam      25.806452
# 100           Indonesia      18.750000
# 102           Sri Lanka      -7.500000
# 110            Thailand      -5.405405
# 112            Mongolia      -2.777778
# 117         Philippines      -2.941176
# 119               Nepal      22.222222
# ...

# %% [markdown]
# <p><b>Задача 2.</b> Анализ рынка акций (4 балла)</p>

# %% [markdown]
# <p>1. Загрузите данные в один dataframe из всех файлов в папке /data/stock. Все файлы имеют одинаковую структуру, в том числе наименование столбцов. В качестве значений индекса dataframe'а необходимо указать значения столбца "Date". Название столбцов должные соответствовать названию акций (имя файла без .csv), а их значения - значениям цены закрытия (столбец "Close" в файлах .csv)</p>

# %%
import os

# скачивал и прописывал пути вручную с ПК, поэтому path надо будет прописать заново, если открывать с другого устройства,
# на data/A1_Descriptive_Analysis/stock/
files = os.listdir("C:\\Users\\vova-\\Documents\\Jupyter\\1\\CSV\\")
# Merge файлов формата .csv в один Dataframe
df = pd.DataFrame(columns=['Date'])
for file in files:
    if file.endswith(".csv"):
        tmp=pd.read_csv("C:\\Users\\vova-\\Documents\\Jupyter\\1\\CSV\\" + file, index_col=0, parse_dates=True)[["Close"]].rename(columns={"Close": file.split(".")[0]})
        df=pd.merge(df, tmp, on='Date', how='outer')
    

df = df.set_index('Date').sort_index().groupby(pd.Grouper(freq='M')).sum()

# %% [markdown]
# <p>2. Рассчитайте корреляционную матрицу для всех акций</p>

# %%
Mycorr.corr()
# Out:
#            ADBE      ADSK      AKAM      BABA      BIDU        CA      CHKP  \
# ADBE   1.000000  0.946633 -0.773309  0.825066  0.972597  0.697628  0.701213
# ADSK   0.946633  1.000000 -0.558971  0.950469  0.922700  0.783771  0.777375
# AKAM  -0.773309 -0.558971  1.000000 -0.372636 -0.765415 -0.418214 -0.309812
# BABA   0.825066  0.950469 -0.372636  1.000000  0.821546  0.849108  0.681441
# BIDU   0.972597  0.922700 -0.765415  0.821546  1.000000  0.804634  0.605961
# CA     0.697628  0.783771 -0.418214  0.849108  0.804634  1.000000  0.357965
# CHKP   0.701213  0.777375 -0.309812  0.681441  0.605961  0.357965  1.000000
# CRM    0.848106  0.731417 -0.817613  0.624540  0.816970  0.533467  0.597505
# CTSH  -0.903080 -0.941880  0.550684 -0.907051 -0.929852 -0.861435 -0.558699
# EBAY  -0.793812 -0.566887  0.902633 -0.320586 -0.743639 -0.240847 -0.420171
# FB     0.990366  0.897934 -0.846945  0.754634  0.972257  0.670390  0.631288
# ...

# %% [markdown]
# <p>3. Отобразите корреляционную матрицу в виде диаграммы. Примерный вид графика приведен ниже</p>
# <img src="img/fig_corr_matrix.png" width="400px">

# %%
figure=plt.figure(figsize=[15, 15])

plt.matshow(Mycorr, fignum=figure.number, vmin=-1, vmax=1)
plt.colorbar()
plt.title('Диаграмма корреляционной матрицы', fontsize=10);
plt.yticks(ticks=range(len(Mycorr.index)), labels=Mycorr.index)
plt.xticks(ticks=range(len(Mycorr.index)), labels=Mycorr.index, rotation=-90)
plt.show()

# %% [markdown]
# <div>
# <p>4. В соответствии с Вашим вариантом определите:</p>
# <ul>
#     <li>акцию с максимальной корреляцией (max)</li>
#     <li>акцию с минимальной корреляцией (min) </li>
#     <li>акцию, которая больше всего соответствует отсутствию какой-либо корреляции (none)</li>
# </ul>
# </div>

# %% [markdown]
# <p><b>Вариант 1.</b> Microsoft (MSFT)</p>
# <p><b>Вариант 2.</b> Facebook (FB)</p>
# <p><b>Вариант 3.</b> Google (GOOGL)</p>
# <p><b>Вариант 4.</b> Alibaba (BABA)</p>

# %%
# Facebook
company="FB"
company_cor = Mycorr[company]
company_cor = company_cor.sort_values()
max_company, min_company = company_cor.iloc[-2:-1].index[0], company_cor.iloc[0:1].index[0]
none_company = company_cor.abs().sort_values().iloc[0:1].index[0]
print("Максимальная корреляция у", max_company)
print("Минимальная корреляция у ", min_company)
print("Нет корреляции у", none_company)
# Out:
# Максимальная корреляция у ADBE
# Минимальная корреляция у  TWTR
# Нет корреляции у RHT

# %% [markdown]
# <p>5. Постройте диаграммы разброса (Ваша компания - Компания с min), (Ваша компания - Компания с max), (Ваша компания - Компания с none)</p>

# %%
# Диаграмма разброса с максимальной корреляцией
plt.figure(figsize=[25, 25])
plt.scatter(df.index, df[company], s=180, label=Company, marker="o", color="blue")
plt.scatter(df.index, df[max_company], s=180, label=f"{max_company} - max", marker="o", color="red")
# Настраиваем график
plt.title(f"{company} and {max_company}")
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# <p>6. Рассчитайте среднюю цену акций для каждого месяца (исходные данные взяты с интервалом в месяц)</p>

# %%
df.T.mean().to_dict()
# Out:
# {Timestamp('2015-03-31 00:00:00', freq='M'): 80.3752182173913,
#  Timestamp('2015-04-30 00:00:00', freq='M'): 81.36043582608694,
#  Timestamp('2015-05-31 00:00:00', freq='M'): 82.68956552173915,
#  Timestamp('2015-06-30 00:00:00', freq='M'): 80.08478143478261,
#  Timestamp('2015-07-31 00:00:00', freq='M'): 86.42521717391305,
#  Timestamp('2015-08-31 00:00:00', freq='M'): 80.80173991304349,
#  Timestamp('2015-09-30 00:00:00', freq='M'): 80.2169565652174,
#  Timestamp('2015-10-31 00:00:00', freq='M'): 90.14869647826086,
#  Timestamp('2015-11-30 00:00:00', freq='M'): 92.99434713043478,
#  Timestamp('2015-12-31 00:00:00', freq='M'): 93.0995656521739,
#  Timestamp('2016-01-31 00:00:00', freq='M'): 87.67478139130436,
#  Timestamp('2016-02-29 00:00:00', freq='M'): 84.96695526086955,
#  Timestamp('2016-03-31 00:00:00', freq='M'): 99.56130608695649,
#  Timestamp('2016-04-30 00:00:00', freq='M'): 96.43260943478262,
#  Timestamp('2016-05-31 00:00:00', freq='M'): 101.78782478260871,
# ...

# %% [markdown]
# <p>7. Постройте графики для акций из пункта 4 и средней из пункта 6. Примерный вид графика приведен ниже</p>
# <img src="img/fig_tw_comp.png">

# %%
plt.figure(figsize=[40, 15])

# Компания
df[company].plot.line(style='-o', linewidth=8, markersize=15, color="red", label=Company)
# Минимальная корреляция
df[min_company].plot.line(style='-o', linewidth=8, markersize=15, color="yellow", label=f'{min_company} - min')
# Максимальная корреляция
df[max_company].plot.line(style='-o', linewidth=8, markersize=15, color="orange", label=f'{max_company} - max')
# Без корреляции
df[none_company].plot.line(style='-o', linewidth=8, markersize=15, color="green", label=f'{none_company} - none')
# Среднее значение
df.T.mean().plot.line(style='-o', linewidth=8, markersize=15, color="blue", label="Mean")

plt.gca().set_ylabel("Графики для акций")
plt.grid()
plt.legend()
plt.show()
